# %% [markdown]
# ## Loading the original data file (saved as a csv from the original Excel file)
#
#
# Import `pandas` (imported as `pd` to save typing).
#
# ```python
# import pandas as pd
# ipos = pd.read_csv('ipos.csv')
# ipos.head()
# ```
#
# Press _shift-enter_ to execute the code.

# %%
import pandas as pd
ipos = pd.read_csv('ipos.csv')
ipos.head()
# Out:
#    Year  Number of IPOs % Profitable  Number of IPOs.1 % Profitable.1
# 0  1980              25          88%                46            70%
# 1  1981              82          81%               110            85%
# 2  1982              44          82%                33            79%
# 3  1983             194          68%               257            86%
# 4  1984              52          81%               121            84%

# %% [markdown]
# ### Rename columns
#
# Rename column names (Excel spreadsheet didn't note which columns were Tech & Biotech and which were Other IPOs.
#
# ```python
# ipos = ipos.rename(columns={
#         'Year': 'year',
#         'Number of IPOs': 'num_ipos_tech',
#         '% Profitable': 'percentprof_tech',
#         'Number of IPOs.1': 'num_ipos_other',
#         '% Profitable.1': 'percentprof_other',
#     })
# ipos.head()
# ```

# %%
ipos = ipos.rename(columns={
        'Year': 'year',
        'Number of IPOs': 'num_ipos_tech',
        '% Profitable': 'percentprof_tech', 
        'Number of IPOs.1': 'num_ipos_other', 
        '% Profitable.1': 'percentprof_other', 
    })
ipos.head()
# Out:
#    year  num_ipos_tech percentprof_tech  num_ipos_other percentprof_other
# 0  1980             25              88%              46               70%
# 1  1981             82              81%             110               85%
# 2  1982             44              82%              33               79%
# 3  1983            194              68%             257               86%
# 4  1984             52              81%             121               84%

# %% [markdown]
# ### Clean data
#
# Remove percentage signs in the % profitable columns and convert the strings to floats, so we just have numbers to work with (the column descriptions also already describe the format of the data).
#
# ```python
# ipos['percentprof_tech'] = ipos['percentprof_tech'].map(lambda x: str(x)[:-1]).astype(float)
# ipos['percentprof_other'] = ipos['percentprof_other'].map(lambda x: str(x)[:-1]).astype(float)
# ipos.head()
# ```

# %%
ipos['percentprof_tech'] = ipos['percentprof_tech'].map(lambda x: str(x)[:-1]).astype(float)
ipos['percentprof_other'] = ipos['percentprof_other'].map(lambda x: str(x)[:-1]).astype(float)
ipos.head()
# Out:
#    year  num_ipos_tech  percentprof_tech  num_ipos_other  percentprof_other
# 0  1980             25                88              46                 70
# 1  1981             82                81             110                 85
# 2  1982             44                82              33                 79
# 3  1983            194                68             257                 86
# 4  1984             52                81             121                 84

# %% [markdown]
# ### Summary statistics
# `describe` function shows basic summary stats for every numeric column in the `DataFrame`
#
# ```python
# ipos.describe()
# ```

# %%
ipos.describe()
# Out:
#               year  num_ipos_tech  percentprof_tech  num_ipos_other  \
# count    35.000000      35.000000         35.000000       35.000000
# mean   1997.000000     102.542857         50.914286      127.742857
# std      10.246951      92.089261         23.243432      100.413950
# min    1980.000000       7.000000         11.000000       14.000000
# 25%    1988.500000      40.500000         31.000000       48.500000
# 50%    1997.000000      72.000000         54.000000       82.000000
# 75%    2005.500000     132.000000         69.500000      199.500000
# max    2014.000000     382.000000         88.000000      355.000000
#
#        percentprof_other
# count          35.000000
# mean           74.085714
# std            10.293834
# min            50.000000
# 25%            69.500000
# 50%            75.000000
# 75%            84.000000
# max            88.000000

# %% [markdown]
# ### Computing number of profitable IPOs for each group
#
# Add a column reflecting the actual number of profitable IPOs for (1) Tech & Biotech and (2) Other.
#
# ```python
# ipos['num_prof_tech'] = ( (ipos['percentprof_tech'] / 100) * ipos['num_ipos_tech'] )
# ipos['num_prof_other'] = ( (ipos['percentprof_other'] / 100) * ipos['num_ipos_other'] )
# ipos.head()
# ```

# %%
ipos['num_prof_tech'] = ( (ipos['percentprof_tech'] / 100) * ipos['num_ipos_tech'] )
ipos['num_prof_other'] = ( (ipos['percentprof_other'] / 100) * ipos['num_ipos_other'] )
ipos['num_loss_tech'] = ( ((100 - ipos['percentprof_tech']) / 100) * ipos['num_ipos_tech'] )
ipos['num_loss_other'] = ( ((100 - ipos['percentprof_other']) / 100) * ipos['num_ipos_other'] )
ipos.head(10)
# Out:
#    year  num_ipos_tech  percentprof_tech  num_ipos_other  percentprof_other  \
# 0  1980             25                88              46                 70
# 1  1981             82                81             110                 85
# 2  1982             44                82              33                 79
# 3  1983            194                68             257                 86
# 4  1984             52                81             121                 84
# 5  1985             42                79             145                 87
# 6  1986            102                64             291                 84
# 7  1987             69                75             216                 85
# 8  1988             30                74              72                 87
# 9  1989             39                69              74                 84
#
#    num_prof_tech  num_prof_other  num_loss_tech  num_loss_other
# 0          22.00           32.20           3.00           13.80
# 1          66.42           93.50          15.58           16.50
# 2          36.08           26.07           7.92            6.93
# 3         131.92          221.02          62.08           35.98
# 4          42.12          101.64           9.88           19.36
# 5          33.18          126.15           8.82           18.85
# 6          65.28          244.44          36.72           46.56
# 7          51.75          183.60          17.25           32.40
# 8          22.20           62.64           7.80            9.36
# 9          26.91           62.16          12.09           11.84

# %% [markdown]
# ## Loading Bokeh for basic visualizations

# %%
from bokeh.charts import Bar, Scatter, output_file, show, output_notebook
from bokeh.sampledata.autompg import autompg as df
from bokeh.models import HoverTool
output_notebook()

scatterplot1 = Scatter(ipos, x='year', y='percentprof_other', title="Percent of profitable companies (other) 1980-2014",
            xlabel="Year")

# output_file("scatterplot.html")

show(scatterplot1)
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="203be3cc-556c-4e6b-96cc-914e65288dc6">Loading BokehJS ...</span>
#     </div>
#     <div class="plotdiv" id="0ad6c827-c673-49f5-b8f1-1ad0d1d0d5fa"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0ad6c827-c673-49f5-b8f1-1ad0d1d0d5fa");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0ad6c827-c673-49f5-b8f1-1ad0d1d0d5fa' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"2908b1f8-64d7-40cb-a5da-6da58b4217eb":{"roots":{"references":[{"attributes":{"plot":{"id":"f4c7c28a-3e4a-485f-ab3f-03f2adfc81cd","subtype":"Chart","type":"Plot"}},"id":"265fdded-b2fd-4697-9d10-d421d8ea5ce0","type":"ResetTool"},{"attributes":{"plot":{"id":"f4c7c28a-3e4a-485f-ab3f-03f2adfc81cd","subtype":"Chart","type":"Plot"}},"id":"add85f1a-ad3d-4d71-ac4b-00241d8703ba","type":"PanTool"},{"attributes":{"callback":null,"end":91.8,"start":46.2},"id":"58f6cf17-80c1-4be4-8bf7-e0536964e913","type":"Range1d"},{"attributes":{"overlay":{"id":"0f3324ad-56cc-4470-8a21-47397b57b806","type":"BoxAnnotation"},"plot":{"id":"f4c7c28a-3e4a-485f-ab3f-03f2adfc81cd","subtype":"Chart","type":"Plot"}},"id":
type":"BoxZoomTool"},{"attributes":{"callback":null,"end":2017.4,"start":1976.6},"id":"99b72a7d-5caf-4ea3-93f6-01ff4430b386","type":"Range1d"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"adb27259-ad0c-4c21-b301-ea2811be1648","type":"Circle"},{"attributes":{"plot":{"id":"f4c7c28a-3e4a-485f-ab3f-03f2adfc81cd","subtype":"Chart","type":"Plot"}},"id":"3cfc577 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[7]</strong>&gt;</code></p>

# %% [markdown]
# ### Tech & Biotech: comparing the number of IPOs to the number of profitable IPOs

# %%
from bokeh.plotting import figure
prof_tech = figure(plot_width=400, plot_height=400)
prof_tech.line(ipos["year"], ipos["num_ipos_tech"],
             color="firebrick", line_width=4, legend="number of tech & biotech IPOs")
prof_tech.line(ipos["year"], ipos["num_prof_tech"],
             color="navy", line_width=4, legend="number of profitable tech & biotech IPOs")
show(prof_tech)
# Out:
#     <div class="plotdiv" id="7295ab1b-4851-44f9-b0c4-f4586c35ffd6"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7295ab1b-4851-44f9-b0c4-f4586c35ffd6");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7295ab1b-4851-44f9-b0c4-f4586c35ffd6' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"b644115b-6351-4c42-9c14-bd2ee763b922":{"roots":{"references":[{"attributes":{"callback":null,"end":2017.4,"start":1976.6},"id":"1de4c2b2-fb9e-4dd5-8ac2-e61fa7ab2603","type":"Range1d"},{"attributes":{},"id":"c0a16322-5a84-40de-9610-ded5f358f8e7","type":"BasicTicker"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"f3b418ab-3d6e-4b3e-8362-25c7763022b6","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"e2715630-0d7a-497c-9e51-8ccbc50a10b8","subtype":"Figure","type":"Plot"}},"id":"954e34e8-0bb9-493a-b9c5-c43a427c0657","type":"ResizeTool"},{"attributes":{"data_source":{"id":"e6766fec-4762-4925-96eb-4cea01d2c7bf","type":"ColumnDataSource"},"glyph":{"id":"0ff6d897-e340-4c76-9415-204c87e392d4","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"117a9b1c-ec60-4a62-a020-c434546217c4","type":"Line"},"selection_glyph":null},"id":"32b9310a-1f06-4e9a-9d9f-56a85ae1d4fc","type":"GlyphRenderer"},{"attributes":{},"id":"04dd8ea7-9588-4e20-8a68-25c9ae5fd3ad","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"f4c7c28a-3e4a-485f-ab3f-03f2adfc81cd","subtype":"Chart","type":"Plot"}},"id":"265fdded-b2fd-4697-9d10-d421d8ea5ce0","type":"ResetTool"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],"x_values":[1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014],"y_values":[70.0,85.0,79.0,86.0,84.0,87.0,84.0,85.0,87.0,84.0,87.0,88.0,80.0,74.0,80.0,75.0,74.0,76.0,69.0,63.0,50.0,66.0,63.0,76.0,70.0,70.0,80.0,74.0,57.0,71.0,71.0,60.0,75.0,56.0,57.0]}},"id":"c5aa8496-cdb1-4449-a6f1-b5a42b033999","type":"ColumnDataSource"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"cc51c629-342f-4d02-9b82-781b700460e9","type":"BoxAnnotation"},{"attributes":{},"id":"ea5f996a-a2e9-4ec4-82b9-3d7f394dea48","type":"ToolEvents"},{"attributes":{"below":[{"id":"380ccd28-9ccd-4641-99dd-4c9a2364ccff","type":"LinearAxis"}],"left":[{"id":"7592edab-5e98-43f6-87a9-58af32761d6d","type":"LinearAxis"}],"legend":null,"renderers":[{"id":"cc51c629-342f-4d02-9b82-781b700460e9","type":"BoxAnnotation"},{"id":"3693e296-7bfa-4def-b059-e4482242337b","type":"GlyphRenderer"},{"id":"380ccd28-9ccd-4641-99dd-4c9a2364ccff","type":"LinearAxis"},{"id":"7592edab-5e98-43f6-87a9-58af32761d6d","type":"LinearAxis"},{"id":"a63b5288-57e2-47e5-8a44-d4fdcbcab308","type":"Grid"},{"id":"e678afc0-db9e-4a84-b485-def6f3a79324","type":"Grid"}],"title":"Percent of profitable companies (tech & biotech) 1980-2014","title_text_font_size":{"value":"14pt"},"tool_events":{"id":"ea5f996a-a2e9-4ec4-82b9-3d7f394dea48","type":"ToolEvents"},"tools":[{"id":"c9514f59-093c-4e6f-958f-43822aaab46d","type":"PanTool"},{"id":"cb14d191-98cd-4ed4-a1fb-150f2def139c","type":"WheelZoomTool"},{"id":"c356b084-a924-4489-bc4c-5f8ae2ae1a50","type":"BoxZoomTool"},{"id":"0f89df53-6c6a-4d2b-bde2-dea570ef22f0","type":"PreviewSaveTool"},{"id":"493f7f42-aec7-46c9-bc92-7b7e3b48ceb7","type":"ResizeTool"},{"id":"d49f5844-acda-4046-8142-3a07927ed426","type":"ResetTool"},{"id":"5b5f9ef3-cde0-4d6d-8782-3eb55c680622","type":"HelpTool"}],"x_mapper_type":"auto","x_range":{"id":"1de4c2b2-fb9e-4dd5-8ac2-e61fa7ab2603","type":"Range1d"},"x ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[8]</strong>&gt;</code></p>

# %% [markdown]
# ### Other: comparing the number of IPOs to the number of profitable IPOs

# %%
from bokeh.plotting import figure
test3 = figure(plot_width=400, plot_height=400)
test3.multi_line([ipos["year"], ipos["year"]], [ipos["num_ipos_other"], ipos["num_prof_other"]],
             color=["firebrick", "navy"], alpha=[0.8, 0.3], line_width=4)
show(test3)
# Out:
#     <div class="plotdiv" id="f35a4f0c-dfd9-4ac4-92ed-4fa0896984bd"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f35a4f0c-dfd9-4ac4-92ed-4fa0896984bd");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f35a4f0c-dfd9-4ac4-92ed-4fa0896984bd' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"b4ccc090-e346-4440-a0a4-2430e6f58b54":{"roots":{"references":[{"attributes":{"plot":{"id":"925d7e02-a3c9-41a3-94c8-105078581791","subtype":"Figure","type":"Plot"}},"id":"6bdde05f-ca1c-4307-b596-943dd4d3c8ce","type":"PreviewSaveTool"},{"attributes":{"formatter":{"id":"56fe9a4e-4c48-4c62-af0b-ebb7e1c59698","type":"BasicTickFormatter"},"plot":{"id":"e2715630-0d7a-497c-9e51-8ccbc50a10b8","subtype":"Figure","type":"Plot"},"ticker":{"id":"c1d116a2-7f93-4d2d-9c52-9f5d3bc8d5da","type":"BasicTicker"}},"id":"52c177ff-1308-4b50-a079-5aa7cdc03be2","type":"LinearAxis"},{"attributes":{"plot":{"id":"e2715630-0d7a-497c-9e51-8ccbc50a10b8","subtype":"Figure","type":"Plot"}},"id":"954e34e8-0bb9-493a-b9c5-c43a427c0657","type":"ResizeTool"},{"attributes":{"line_alpha":{"field":"line_alpha"},"line_color":{"field":"line_color"},"line_width":{"value":4},"xs":{"field":"xs"},"ys":{"field":"ys"}},"id":"bf080e66-a99d-4815-8902-4226c5fc7ed6","type":"MultiLine"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":4},"xs":{"field":"xs"},"ys":{"field":"ys"}},"id":"7d88f651-69dd-44bb-8adc-b117d69b374d","type":"MultiLine"},{"attributes":{"plot":{"id":"925d7e02-a3c9-41a3-94c8-105078581791","subtype":"Figure","type":"Plot"}},"id":"88b74930-6c61-4577-bec6-1533c6272083","type":"ResizeTool"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"adb27259-ad0c-4c21-b301-ea2811be1648","type":"Circle"},{"attributes":{"plot":{"id":"e2715630-0d7a-497c-9e51-8ccbc50a10b8","subtype":"Figure","type":"Plot"}},"id":"ef946aae-a35a-4ad2-8310-6f8e466f8068","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"f4c7c28a-3e4a-485f-ab3f-03f2adfc81cd","subtype":"Chart","type":"Plot"}},"id":"fb29de1f-455e-4fab-9f33-f726b903bcd1","type":"ResizeTool"},{"attributes":{"axis_label":"Year","formatter":{"id":"b093fe45-00d0-4fb6-8b4d-8a198790d7bf","type":"BasicTickFormatter"},"plot":{"id":"f400718c-6688-490b-a567-2ac331b77bda","subtype":"Chart","type":"Plot"},"ticker":{"id":"2759aab1-f29c-4ed9-a063-3ff2a91e2136","type":"BasicTicker"}},"id":"380ccd28-9ccd-4641-99dd-4c9a2364ccff","type":"LinearAxis"},{"attributes":{},"id":"8f5c7837-1cd5-41ff-ba48-6864b4940712","type":"ToolEvents"},{"attributes":{"plot":{"id":"e2715630-0d7a-497c-9e51-8ccbc50a10b8","subtype":"Figure","type":"Plot"}},"id":"907419ac-c92f-481d-8c44-46f71dcfdec5","type":"PanTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":4},"x":{"field":"x"},"y":{"field":"y"}},"id":"117a9b1c-ec60-4a62-a020-c434546217c4","type":"Line"},{"attributes":{"axis_label":"percentprof_tech","formatter":{"id":"04dd8ea7-9588-4e20-8a68-25c9ae5fd3ad","type":"BasicTickFormatter"},"plot":{"id":"f400718c-6688-490b-a567-2ac331b77bda","subtype":"Chart","type":"Plot"},"ticker":{"id":"af053057-bc43-43e0-b5ce-b7e675057b8c","type":"BasicTicker"}},"id":"7592edab-5e98-43f6-87a9-58af32761d6d","type":"LinearAxis"},{"attributes":{"plot":{"id":"f400718c-6688-490b-a567-2ac331b77bda","subtype":"Chart","type":"Plot"}},"id":"493f7f42-aec7-46c9-bc92-7b7e3b48ceb7","type":"ResizeTool"},{"attributes":{"callback":null},"id":"d7cb747a-9ac2-4f71-9d1f-9e3c15751000","type":"DataRange1d"},{"attributes":{},"id":"f079a367-f651-488b-b7e5-facff8c24e34","type":"BasicTickFormatter"},{"attributes":{},"id":"c1d116a2-7f93-4d2d-9c52-9f5d3bc8d5da","type":"BasicTicker"},{"attributes":{},"id":"85f25e51-3c8a-4eef-a83a-27afe4ae1151","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"f562350a-cfa2-4297-ac2c-96121767cb57","type":"ColumnDataSource"},"glyph":{"id":"bf080e66-a99d-4815-8902-4226c5fc7ed6","type":"MultiLine"},"hover_glyph":null,"nonselection_glyph":{"id":"7d88f651-69dd-44bb-8adc-b117d69b374d","type":"MultiLine"},"selection_glyph":null},"id":"4ba6206f-2729-48a6-aa49-7356113f50a8","type":"GlyphRenderer"},{"attribute ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[9]</strong>&gt;</code></p>

# %% [markdown]
# ### Comparing "tech & biotech" vs. "other" in terms of % profitable IPOs

# %%
x1 = ipos["year"]
y1 = ipos["percentprof_tech"]
x2 = ipos["year"]
y2 = ipos["percentprof_other"]

percentprof = figure(plot_width=400, plot_height=400)
percentprof.multi_line([x1, x2], [y1, y2],
             color=["firebrick", "navy"], alpha=[0.8, 0.3], line_width=4)

show(percentprof)
# Out:
#     <div class="plotdiv" id="8306e79b-9f8c-4d40-a890-636e6e677d02"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8306e79b-9f8c-4d40-a890-636e6e677d02");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8306e79b-9f8c-4d40-a890-636e6e677d02' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"a91338fa-f32f-4a2e-8d3c-148d21dafa82":{"roots":{"references":[{"attributes":{"plot":{"id":"925d7e02-a3c9-41a3-94c8-105078581791","subtype":"Figure","type":"Plot"}},"id":"6bdde05f-ca1c-4307-b596-943dd4d3c8ce","type":"PreviewSaveTool"},{"attributes":{"formatter":{"id":"56fe9a4e-4c48-4c62-af0b-ebb7e1c59698","type":"BasicTickFormatter"},"plot":{"id":"e2715630-0d7a-497c-9e51-8ccbc50a10b8","subtype":"Figure","type":"Plot"},"ticker":{"id":"c1d116a2-7f93-4d2d-9c52-9f5d3bc8d5da","type":"BasicTicker"}},"id":"52c177ff-1308-4b50-a079-5aa7cdc03be2","type":"LinearAxis"},{"attributes":{"plot":{"id":"e2715630-0d7a-497c-9e51-8ccbc50a10b8","subtype":"Figure","type":"Plot"}},"id":"954e34e8-0bb9-493a-b9c5-c43a427c0657","type":"ResizeTool"},{"attributes":{"plot":{"id":"981c8f30-25d8-49ea-9acc-7017a660297c","subtype":"Figure","type":"Plot"}},"id":"741a36f0-5ac2-4202-b359-fd4569a83f9f","type":"ResizeTool"},{"attributes":{"line_alpha":{"field":"line_alpha"},"line_color":{"field":"line_color"},"line_width":{"value":4},"xs":{"field":"xs"},"ys":{"field":"ys"}},"id":"bf080e66-a99d-4815-8902-4226c5fc7ed6","type":"MultiLine"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":4},"xs":{"field":"xs"},"ys":{"field":"ys"}},"id":"7d88f651-69dd-44bb-8adc-b117d69b374d","type":"MultiLine"},{"attributes":{},"id":"be631843-d2a1-49ea-9440-d01dea5a8022","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"925d7e02-a3c9-41a3-94c8-105078581791","subtype":"Figure","type":"Plot"}},"id":"88b74930-6c61-4577-bec6-1533c6272083","type":"ResizeTool"},{"attributes":{"plot":{"id":"981c8f30-25d8-49ea-9acc-7017a660297c","subtype":"Figure","type":"Plot"}},"id":"312cda1f-5e8a-47b1-b250-b8e1b89ff48c","type":"ResetTool"},{"attributes":{"plot":{"id":"981c8f30-25d8-49ea-9acc-7017a660297c","subtype":"Figure","type":"Plot"}},"id":"317b96b0-12e3-4898-952d-81f779a2ba6f","type":"PreviewSaveTool"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"adb27259-ad0c-4c21-b301-ea2811be1648","type":"Circle"},{"attributes":{"plot":{"id":"e2715630-0d7a-497c-9e51-8ccbc50a10b8","subtype":"Figure","type":"Plot"}},"id":"ef946aae-a35a-4ad2-8310-6f8e466f8068","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"f4c7c28a-3e4a-485f-ab3f-03f2adfc81cd","subtype":"Chart","type":"Plot"}},"id":"fb29de1f-455e-4fab-9f33-f726b903bcd1","type":"ResizeTool"},{"attributes":{"axis_label":"Year","formatter":{"id":"b093fe45-00d0-4fb6-8b4d-8a198790d7bf","type":"BasicTickFormatter"},"plot":{"id":"f400718c-6688-490b-a567-2ac331b77bda","subtype":"Chart","type":"Plot"},"ticker":{"id":"2759aab1-f29c-4ed9-a063-3ff2a91e2136","type":"BasicTicker"}},"id":"380ccd28-9ccd-4641-99dd-4c9a2364ccff","type":"LinearAxis"},{"attributes":{},"id":"8f5c7837-1cd5-41ff-ba48-6864b4940712","type":"ToolEvents"},{"attributes":{"plot":{"id":"e2715630-0d7a-497c-9e51-8ccbc50a10b8","subtype":"Figure","type":"Plot"}},"id":"907419ac-c92f-481d-8c44-46f71dcfdec5","type":"PanTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":4},"x":{"field":"x"},"y":{"field":"y"}},"id":"117a9b1c-ec60-4a62-a020-c434546217c4","type":"Line"},{"attributes":{"axis_label":"percentprof_tech","formatter":{"id":"04dd8ea7-9588-4e20-8a68-25c9ae5fd3ad","type":"BasicTickFormatter"},"plot":{"id":"f400718c-6688-490b-a567-2ac331b77bda","subtype":"Chart","type":"Plot"},"ticker":{"id":"af053057-bc43-43e0-b5ce-b7e675057b8c","type":"BasicTicker"}},"id":"7592edab-5e98-43f6-87a9-58af32761d6d","type":"LinearAxis"},{"attributes":{"plot":{"id":"f400718c-6688-490b-a567-2ac331b77bda","subtype":"Chart","type":"Plot"}},"id":"493f7f42-aec7-46c9-bc92-7b7e3b48ceb7","type":"ResizeTool"},{"attributes":{"callback":null},"id":"d7cb747a-9ac2-4f71-9d1f-9e3c15751000","type":"DataRange1d"},{"attributes":{},"id":"f079a367-f651-488b-b7e5-fac ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[10]</strong>&gt;</code></p>

# %% [markdown]
# ### Create new table grouping percent profitability of IPOs in 5 year ranges

# %%
start = 1980
end = 1984
percent_prof_tech = 0
percent_prof_other = 0
year_range = []
tech_data = []
other_data = []

for pos, i in enumerate(ipos["year"].tolist(), 0):
    percent_prof_tech += ipos["percentprof_tech"][pos]
    percent_prof_other += ipos["percentprof_other"][pos]
    if (pos+1) % 5 == 0:
        year_range.append("%s-%s" % (start,end))
        start += 5
        end += 5
        tech_data.append((percent_prof_tech / 500) * 100)
        other_data.append((percent_prof_other / 500) * 100)
        percent_prof_tech = 0
        percent_prof_other = 0

d = {'year_range': pd.Series(year_range),
     'percent_prof_other': pd.Series(other_data),
     'percent_prof_tech': pd.Series(tech_data)
    }

grouped_years = pd.DataFrame(d)
grouped_years = grouped_years[grouped_years.columns[::-1]]
grouped_years
# Out:
#   year_range  percent_prof_tech  percent_prof_other
# 0  1980-1984               80.0                80.8
# 1  1985-1989               72.2                85.4
# 2  1990-1994               63.8                81.8
# 3  1995-1999               41.0                71.4
# 4  2000-2004               27.6                65.0
# 5  2005-2009               43.4                70.4
# 6  2010-2014               28.4                63.8

# %% [markdown]
# ### Save new CSV

# %%
grouped_years.to_csv('to_chart.csv', index=False, encoding='utf-8')

# %% [markdown]
# ### Bar charts to compare tech & biotech vs. other in percentage of profitable IPOs from 1980-2014

# %%
data = pd.DataFrame({'Group' :['Tech & Biotech','Other','Tech & Biotech','Other','Tech & Biotech','Other','Tech & Biotech','Other','Tech & Biotech','Other','Tech & Biotech','Other','Tech & Biotech','Other'],
                     'Year Range'  :['1980-1984','1980-1984','1985-1989','1985-1989','1990-1994','1990-1994','1995-1999','1995-1999','2000-2004','2000-2004','2004-2009','2004-2009','2010-2014','2010-2014'],
                     'Percent Profitable IPOs':[80.0, 80.8, 72.2, 85.4, 63.8, 81.8, 41.00, 71.4, 27.6, 65.0, 43.4, 70.4, 28.4, 63.8]})
fig = Bar(data, label='Year Range', values='Percent Profitable IPOs', group='Group', legend='top_right')
show(fig)
# Out:
#     <div class="plotdiv" id="41b702f3-3929-4c4f-b740-f8ffafa587f7"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("41b702f3-3929-4c4f-b740-f8ffafa587f7");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '41b702f3-3929-4c4f-b740-f8ffafa587f7' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"40643601-cd98-4e6e-9093-741e8adc895c":{"roots":{"references":[{"attributes":{"plot":{"id":"925d7e02-a3c9-41a3-94c8-105078581791","subtype":"Figure","type":"Plot"}},"id":"6bdde05f-ca1c-4307-b596-943dd4d3c8ce","type":"PreviewSaveTool"},{"attributes":{"formatter":{"id":"56fe9a4e-4c48-4c62-af0b-ebb7e1c59698","type":"BasicTickFormatter"},"plot":{"id":"e2715630-0d7a-497c-9e51-8ccbc50a10b8","subtype":"Figure","type":"Plot"},"ticker":{"id":"c1d116a2-7f93-4d2d-9c52-9f5d3bc8d5da","type":"BasicTicker"}},"id":"52c177ff-1308-4b50-a079-5aa7cdc03be2","type":"LinearAxis"},{"attributes":{"plot":{"id":"e2715630-0d7a-497c-9e51-8ccbc50a10b8","subtype":"Figure","type":"Plot"}},"id":"954e34e8-0bb9-493a-b9c5-c43a427c0657","type":"ResizeTool"},{"attributes":{"plot":{"id":"981c8f30-25d8-49ea-9acc-7017a660297c","subtype":"Figure","type":"Plot"}},"id":"741a36f0-5ac2-4202-b359-fd4569a83f9f","type":"ResizeTool"},{"attributes":{"line_alpha":{"field":"line_alpha"},"line_color":{"field":"line_color"},"line_width":{"value":4},"xs":{"field":"xs"},"ys":{"field":"ys"}},"id":