# %% [markdown]
# ## Loading the original data file (saved as a csv from the original Excel file)
#
#
# Import `pandas` (imported as `pd` to save typing).
#
# ```python
# import pandas as pd
# ipos = pd.read_csv('ipos.csv')
# ipos.head()
# ```
#
# Press _shift-enter_ to execute the code.

# %%
import pandas as pd
ipos = pd.read_csv('ipos.csv')
ipos.head()
# Out:
#    Year  Number of IPOs % Profitable  Number of IPOs.1 % Profitable.1
# 0  1980              25          88%                46            70%
# 1  1981              82          81%               110            85%
# 2  1982              44          82%                33            79%
# 3  1983             194          68%               257            86%
# 4  1984              52          81%               121            84%

# %% [markdown]
# ### Rename columns
#
# Rename column names (Excel spreadsheet didn't note which columns were Tech & Biotech and which were Other IPOs.
#
# ```python
# ipos = ipos.rename(columns={
#         'Year': 'year',
#         'Number of IPOs': 'num_ipos_tech',
#         '% Profitable': 'percentprof_tech',
#         'Number of IPOs.1': 'num_ipos_other',
#         '% Profitable.1': 'percentprof_other',
#     })
# ipos.head()
# ```

# %%
ipos = ipos.rename(columns={
        'Year': 'year',
        'Number of IPOs': 'num_ipos_tech',
        '% Profitable': 'percentprof_tech', 
        'Number of IPOs.1': 'num_ipos_other', 
        '% Profitable.1': 'percentprof_other', 
    })
ipos.head()
# Out:
#    year  num_ipos_tech percentprof_tech  num_ipos_other percentprof_other
# 0  1980             25              88%              46               70%
# 1  1981             82              81%             110               85%
# 2  1982             44              82%              33               79%
# 3  1983            194              68%             257               86%
# 4  1984             52              81%             121               84%

# %% [markdown]
# ### Clean data
#
# Remove percentage signs in the % profitable columns and convert the strings to floats, so we just have numbers to work with (the column descriptions also already describe the format of the data).
#
# ```python
# ipos['percentprof_tech'] = ipos['percentprof_tech'].map(lambda x: str(x)[:-1]).astype(float)
# ipos['percentprof_other'] = ipos['percentprof_other'].map(lambda x: str(x)[:-1]).astype(float)
# ipos.head()
# ```

# %%
ipos['percentprof_tech'] = ipos['percentprof_tech'].map(lambda x: str(x)[:-1]).astype(float)
ipos['percentprof_other'] = ipos['percentprof_other'].map(lambda x: str(x)[:-1]).astype(float)
ipos.head()
# Out:
#    year  num_ipos_tech  percentprof_tech  num_ipos_other  percentprof_other
# 0  1980             25                88              46                 70
# 1  1981             82                81             110                 85
# 2  1982             44                82              33                 79
# 3  1983            194                68             257                 86
# 4  1984             52                81             121                 84

# %% [markdown]
# ### Summary statistics
# `describe` function shows basic summary stats for every numeric column in the `DataFrame`
#
# ```python
# ipos.describe()
# ```

# %%
ipos.describe()
# Out:
#               year  num_ipos_tech  percentprof_tech  num_ipos_other  \
# count    35.000000      35.000000         35.000000       35.000000
# mean   1997.000000     102.542857         50.914286      127.742857
# std      10.246951      92.089261         23.243432      100.413950
# min    1980.000000       7.000000         11.000000       14.000000
# 25%    1988.500000      40.500000         31.000000       48.500000
# 50%    1997.000000      72.000000         54.000000       82.000000
# 75%    2005.500000     132.000000         69.500000      199.500000
# max    2014.000000     382.000000         88.000000      355.000000
#
#        percentprof_other
# count          35.000000
# mean           74.085714
# std            10.293834
# min            50.000000
# 25%            69.500000
# 50%            75.000000
# 75%            84.000000
# max            88.000000

# %% [markdown]
# ### Computing number of profitable IPOs for each group
#
# Add a column reflecting the actual number of profitable IPOs for (1) Tech & Biotech and (2) Other.
#
# ```python
# ipos['num_prof_tech'] = ( (ipos['percentprof_tech'] / 100) * ipos['num_ipos_tech'] )
# ipos['num_prof_other'] = ( (ipos['percentprof_other'] / 100) * ipos['num_ipos_other'] )
# ipos.head()
# ```

# %%
ipos['num_prof_tech'] = ( (ipos['percentprof_tech'] / 100) * ipos['num_ipos_tech'] )
ipos['num_prof_other'] = ( (ipos['percentprof_other'] / 100) * ipos['num_ipos_other'] )
ipos['num_loss_tech'] = ( ((100 - ipos['percentprof_tech']) / 100) * ipos['num_ipos_tech'] )
ipos['num_loss_other'] = ( ((100 - ipos['percentprof_other']) / 100) * ipos['num_ipos_other'] )
ipos.head(10)
# Out:
#    year  num_ipos_tech  percentprof_tech  num_ipos_other  percentprof_other  \
# 0  1980             25                88              46                 70
# 1  1981             82                81             110                 85
# 2  1982             44                82              33                 79
# 3  1983            194                68             257                 86
# 4  1984             52                81             121                 84
# 5  1985             42                79             145                 87
# 6  1986            102                64             291                 84
# 7  1987             69                75             216                 85
# 8  1988             30                74              72                 87
# 9  1989             39                69              74                 84
#
#    num_prof_tech  num_prof_other  num_loss_tech  num_loss_other
# 0          22.00           32.20           3.00           13.80
# 1          66.42           93.50          15.58           16.50
# 2          36.08           26.07           7.92            6.93
# 3         131.92          221.02          62.08           35.98
# 4          42.12          101.64           9.88           19.36
# 5          33.18          126.15           8.82           18.85
# 6          65.28          244.44          36.72           46.56
# 7          51.75          183.60          17.25           32.40
# 8          22.20           62.64           7.80            9.36
# 9          26.91           62.16          12.09           11.84

# %% [markdown]
# ## Loading Bokeh for basic visualizations

# %%
from bokeh.charts import Bar, Scatter, output_file, show, output_notebook
from bokeh.sampledata.autompg import autompg as df
from bokeh.models import HoverTool
output_notebook()

scatterplot = Scatter(ipos, x='year', y='num_prof_tech', title="Number of profitable tech & biotech companies",
            xlabel="Year")

# output_file("scatterplot.html")

# show(scatterplot)
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="f24406d2-a7c0-4911-919d-f9b57c0a0b4b">Loading BokehJS ...</span>
#     </div>

# %%
# from bokeh.charts import Bar
# p = Bar(
#     ipos, label='year', values='num_ipos_tech', title="Profitable IPOs", tools='crosshair'
# )

p = Scatter(ipos, x='year', y='percentprof_tech', title="Number of profitable tech & biotech companies",
            xlabel="Year")

show(p)
# Out:
#     <div class="plotdiv" id="78588704-ad1c-4106-982b-3af65004ae7d"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("78588704-ad1c-4106-982b-3af65004ae7d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '78588704-ad1c-4106-982b-3af65004ae7d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"9800d28b-cbc0-4d5d-963f-9ed927064e88":{"roots":{"references":[{"attributes":{"axis_label":"Year","formatter":{"id":"9f7464e5-7c4a-4830-9429-e60c912c737a","type":"BasicTickFormatter"},"plot":{"id":"ea4a1a45-04d9-4e52-8eb7-ff5c8f952001","subtype":"Chart","type":"Plot"},"ticker":{"id":"9b0dd597-f12e-49da-b6a3-1781d641d9ee","type":"BasicTicker"}},"id":"b42b57b0-6e63-4dd2-8435-dafccff51605","type":"LinearAxis"},{"attributes":{"plot":{"id":"0101c355-0f73-4f8f-88f7-51abed44be44","subtype":"Chart","type":"Plot"}},"id":"07ac9e77-9769-4449-b7d4-3fd57a9edd11","type":"ResizeTool"},{"attributes":{"plot":{"id":"0101c355-0f73-4f8f-88f7-51abed44be44","subtype":"Chart","type":"Plot"}},"id":"6667bd9f-9220-4d9f-9278-fd0871ea334c","type":"ResetTool"},{"attributes":{"plot":{"id":"ea4a1a45-04d9-4e52-8eb7-ff5c8f952001","subtype":"Chart","type":"Plot"}},"id":"67f88a2d-72de-4812-9eb0-a5def82392cf","type":"WheelZoomTool"},{"attributes":{},"id":"7d6fde04-a9f5-4417-82e4-2e35bb99dce5","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"c598e729-3434-4013-b32a-e7c4574cc88d","type":"Circle"},{"attributes":{"data_source":{"id":"c41e499f-2eea-4731-b174-a4538d73e682","type":"ColumnDataSource"},"glyph":{"id":"2a3d5213-8e56-4987-a381-dc42a89b23ff","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"f8303759-8991-4b0e-9a71-84ee436da5ea","type":"GlyphRenderer"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"8c8b4493-c46a-48f4-ab1f-b995631532d3","type":"BoxAnnotation"},{"attributes":{},"id":"9f7464e5-7c4a-4830-9429-e60c912c737a","type":"BasicTickFormatter"},{"attributes":{},"id":"6e4f32e0-0fea-4ac8-bb27-56289ed00903","type":"ToolEvents"},{"attributes":{},"id":"ea5ed697-934d-427e-98e5-11f0c10f4dcf","type":"BasicTicker"},{"attributes":{"axis_label":"percentprof_tech","formatter":{"id":"46cbfee6-b33b-4ee5-93f9-71d37589c07a","type":"BasicTickFormatter"},"plot":{"id":"ea4a1a45-04d9-4e52-8eb7-ff5c8f952001","subtype":"Chart","type":"Plot"},"ticker":{"id":"0cdd3709-c139-4edc-9440-437165d3c20f","type":"BasicTicker"}},"id":"4cac106e-1c63-473b-887e-33373550b4b7","type":"LinearAxis"},{"attributes":{"plot":{"id":"ea4a1a45-04d9-4e52-8eb7-ff5c8f952001","subtype":"Chart","type":"Plot"}},"id":"cb4e54c7-f05a-4921-b8fd-e7420aae0f1d","type":"HelpTool"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],"x_values":[1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014],"y_values":[88.0,81.0,82.0,68.0,81.0,79.0,64.0,75.0,74.0,69.0,83.0,55.0,54.0,64.0,63.0,65.0,43.0,46.0,37.0,14.0,13.0,24.0,42.0,27.0,32.0,30.0,36.0,24.0,57.0,70.0,48.0,29.0,35.0,19.0,11.0]}},"id":"f4242d40-43fc-4f63-98ae-95ea9507f08a","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"ea4a1a45-04d9-4e52-8eb7-ff5c8f952001","subtype":"Chart","type":"Plot"}},"id":"d44f4a93-c15a-4ce7-aa56-dee7dafec315","type":"ResetTool"},{"attributes":{"callback":null,"end":2017.4,"start":1976.6},"id":"86575706-b4bc-488c-aef5-9c37c401ca2c","type":"Range1d"},{"attributes":{"callback":null,"end":2017.4,"start":1976.6},"id":"6306406e-d233-489c-9a4e-6872266a58ed","type":"Range1d"},{"attributes":{},"id":"0cdd3709-c139-4edc-9440-437165d3c20f","type":"BasicTicker"},{"attributes":{"bottom_units": ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[7]</strong>&gt;</code></p>

# %% [markdown]
# ### Tech & Biotech: comparing the number of IPOs to the number of profitable IPOs

# %%
prof_tech = figure(plot_width=400, plot_height=400)
prof_tech.line(ipos["year"], ipos["num_ipos_tech"],
             color="firebrick", line_width=4, legend="number of tech & biotech IPOs")
prof_tech.line(ipos["year"], ipos["num_prof_tech"],
             color="navy", line_width=4, legend="number of profitable tech & biotech IPOs")
# prof_tech.multi_line([ipos["year"], ipos["year"]], [ipos["num_ipos_tech"], ipos["num_prof_tech"]],
#              color=["firebrick", "navy"], alpha=[0.8, 0.3], line_width=4)
# add optional circles
# test2.circle(ipos["year"], ipos["num_ipos_tech"],
#              fill_color="white", size=6)
# test2.circle(ipos["year"], ipos["num_prof_tech"],
#              fill_color="black", size=6)
show(prof_tech)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-fe7f4c2e6643> in <module>()
# ----> 1 prof_tech = figure(plot_width=400, plot_height=400)
#       2 prof_tech.line(ipos["year"], ipos["num_ipos_tech"],
#       3              color="firebrick", line_width=4, legend="number of tech & biotech IPOs")
#       4 prof_tech.line(ipos["year"], ipos["num_prof_tech"],
#       5              color="navy", line_width=4, legend="number of profitable tech & biotech IPOs")
#
# NameError: name 'figure' is not defined

# %% [markdown]
# ### Other: comparing the number of IPOs to the number of profitable IPOs

# %%
from bokeh.plotting import figure
test3 = figure(plot_width=400, plot_height=400)
test3.multi_line([ipos["year"], ipos["year"]], [ipos["num_ipos_other"], ipos["num_prof_other"]],
             color=["firebrick", "navy"], alpha=[0.8, 0.3], line_width=4)
show(test3)

# %% [markdown]
# ### Comparing "tech & biotech" vs. "other" in terms of % profitable IPOs

# %%
x1 = ipos["year"]
y1 = ipos["percentprof_tech"]
x2 = ipos["year"]
y2 = ipos["percentprof_other"]

percentprof = figure(plot_width=400, plot_height=400)
percentprof.multi_line([x1, x2], [y1, y2],
             color=["firebrick", "navy"], alpha=[0.8, 0.3], line_width=4)
# percentprof_tech.circle(x1, y1, fill_color="white", size=8)

show(percentprof)

# %% [raw]
# ### Percent of Profitable IPOs (tech & biotech)

# %%
p = Bar(ipos, 'year', values='percentprof_tech', title="% of Profitable Tech & Biotech IPOs")
show(p)
# Out:
#     <div class="plotdiv" id="765dd490-db14-4330-8405-ad7900dbf962"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("765dd490-db14-4330-8405-ad7900dbf962");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '765dd490-db14-4330-8405-ad7900dbf962' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"4d550c47-1f76-4422-bab5-8c87efdc4f5e":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"86bea4cb-a025-4efe-ad15-7183f21a4af3","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a2800b05-588a-49da-bf8b-c7869006952a","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x"],"data":{"chart_index":[{"year":1982}],"color":["#407ee7"],"fill_alpha":[0.8],"height":[82.0],"line_alpha":[1.0],"line_color":["white"],"width":[0.02002281575987929],"x":["1982:0.0833333333333"],"y":[41.0],"year":[1982]}},"id":"941e10e0-b482-45e9-b087-d7c815c0b89b","type":"ColumnDataSource"},{"attributes":{"dimension":1,"plot":{"id":"79f2a849-22ac-4f6a-9224-c2aae23b0c34","subtype":"Chart","type":"Plot"},"ticker":{"id":"f3889145-1a37-46e9-84ef-696ff55b09c6","type":"BasicTicker"}},"id":"73ec4712-78da-4fc1-9eb0-bb26e03f460b","type":"Grid"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x"],"data":{"chart_index":[{"year":2003}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[27.0],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["2003"],"y":[13.5],"year":[2003]}},"id":"87348bae-ce75-4533-a5e0-f2fe7c183f0a","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e42cc0f4-0701-40f3-809e-a486bf070eca","type":"Rect"},{"attributes":{"data_source":{"id":"34bcda61-34cf-4157-8f6c-384a995f33f5","type":"ColumnDataSource"},"glyph":{"id":"94219828-899f-4a63-9e86-6527cf980eb5","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"516b372a-7fff-4816-8c7c-6be89aa032cf","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"8938ca0e-5133-4239-aff9-025bd1c0a33b","type":"ColumnDataSource"},"glyph":{"id":"b99a670b-3997-4605-bcd7-8683643aa41d","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"c0747da3-428a-4123-b7db-8e5ecfc414c9","type":"GlyphRenderer"},{"attributes":{},"id":"c8f101ef-9872-49b0-9738-2633d2832aa9","type":"CategoricalTicker"},{"attributes":{"data_source":{"id":"e31d79c4-4f34-401b-aa5a-b19fe49bb640","type":"ColumnDataSource"},"glyph":{"id":"8e667889-8dab-49fe-9cf0-77a0ad02b68d","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"d0dfe6e6-e57c-4cbe-84dd-a465be6440df","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"02940539-1d9a-4996-a5cf-47ff01923655","type":"Rect"},{"attributes":{"plot":{"id":"f35c2726-66aa-47ee-a759-1c3dcdf37821","subtype":"Chart","type":"Plot"}},"id":"bb1804d2-91df-403a-83ac-019e0bb3d797","type":"ResizeTool"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4a4fe9ad-08e3-40e7-876b-868eac0161b0","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x"],"data":{"chart_index":[{"year":2008}],"color":["#f22c40"],"fill_alpha":[0.8],"heigh ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[76]</strong>&gt;</code></p>

# %%
p = Bar(ipos, 'year', values='percentprof_other', title="% of Profitable Other IPOs")
show(p)
# Out:
#     <div class="plotdiv" id="83766b67-6ef0-405f-a739-7bf843dcf4e0"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("83766b67-6ef0-405f-a739-7bf843dcf4e0");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '83766b67-6ef0-405f-a739-7bf843dcf4e0' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"8cd95837-4669-4955-bc46-170346c47d82":{"roots":{"references":[{"attributes":{"data_source":{"id":"ead144f2-1964-484f-8b94-29cbbc6cd7fd","type":"ColumnDataSource"},"glyph":{"id":"f00cd6fa-8cb6-43cd-877e-b4a2984ae2db","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"39503bbf-adb7-4bdd-b625-fe12288fb652","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e42cc0f4-0701-40f3-809e-a486bf070eca","type":"Rect"},{"attributes":{},"id":"c8f101ef-9872-49b0-9738-2633d2832aa9","type":"CategoricalTicker"},{"attributes":{"data_source":{"id":"ef3dffc8-b7da-46a8-a28c-355fe4a980d0","type":"ColumnDataSource"},"glyph":{"id":"9cffe588-89ba-4bf9-bf98-6d011eaf0d8b","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"51b31135-ebcf-4346-a032-2affb9676b03","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"b33d1004-6b45-48fc-b239-af6ed405be33","type":"ColumnDataSource"},"glyph":{"id":"15473724-6bad-469a-bc13-a4d28ba87fbd","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"3d6c2c12-0367-47fc-822e-0f2d859a87fd","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"5e8d2666-56f5-476c-8f63-0814ab128874","type":"ColumnDataSource"},"glyph":{"id":"63b1070c-339a-4c94-8cf8-e0354b682246","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"54a702da-214e-4bcc-8b75-6da38a367243","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"be7b0422-2d81-4d2a-a093-87853767e334","type":"Rect"},{"attributes":{"data_source":{"id":"5a6a3cfa-6f43-4600-ad5f-55b3ed9cb944","type":"ColumnDataSource"},"glyph":{"id":"65b83faf-88de-4529-95b6-530350ed3503","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"54ee0de2-6094-4f0c-8ab6-e0831a2d64fb","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"23ca8fc1-6110-49b4-a715-0a025774f396","type":"ColumnDataSource"},"glyph":{"id":"4195e979-c45c-43e7-851c-550392a5f3fc","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"1098f235-c3f7-4b13-88cd-dfcd4f6795a2","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x"],"data":{"chart_index":[{"year":1983}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[257.0],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["1983"],"y":[128.5],"year":[1983]}},"id":"30b7eff6-98f0-4350-a06f-55224b752fe7","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"823f082d-2ff8-4069-b0f5-97804d9a8744","subtype":"Chart","type":"Plot"}},"id":"4d9a312e-244d-4036-8ee4-3ae1536542ba","type":"PanTool"},{"attributes":{"data_source":{"id":"53fc9a57-b71d-4bcb-a0a5-a61a25b759f5","type":"ColumnDataSource"},"glyph":{"id":"54b8c540-ce1a-4a87-98c6-45b5e188bea2","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"e4f103dc-e6ed-4fcc-a5de-e8482c310b63","type":"GlyphRenderer"},{"attributes":{},"id":"0e914808-5a13-4864-af20-c09ef0580313","type":"CategoricalTickFormatter"},{"attributes":{"data_source":{"id":"5874eafe-9a42-4a85-b4f9-0f52afafd7b4","type":"ColumnDataSource"},"glyph":{"id":"3c04f79c-024a-46d2-9c95-44fbcd44700e","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"25335b55-1f19-486b-ad6b-66735ce4fea2","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_col ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[78]</strong>&gt;</code></p>

# %% [markdown]
# ### Create new table grouping percent profitability of IPOs in 5 year ranges

# %%
start = 1980
end = 1984
percent_prof_tech = 0
percent_prof_other = 0
year_range = []
tech_data = []
other_data = []

for pos, i in enumerate(ipos["year"].tolist(), 0):
    percent_prof_tech += ipos["percentprof_tech"][pos]
    percent_prof_other += ipos["percentprof_other"][pos]
    if (pos+1) % 5 == 0:
        year_range.append("%s-%s" % (start,end))
        start += 5
        end += 5
        tech_data.append((percent_prof_tech / 500) * 100)
        other_data.append((percent_prof_other / 500) * 100)
        percent_prof_tech = 0
        percent_prof_other = 0

d = {'year range': pd.Series(year_range),
     'percent prof other': pd.Series(other_data),
     'percent prof tech': pd.Series(tech_data)
    }

grouped_years = pd.DataFrame(d)
grouped_years = grouped_years[grouped_years.columns[::-1]]
grouped_years
# Out:
#   year range  percent prof tech  percent prof other
# 0  1980-1984               80.0                80.8
# 1  1985-1989               72.2                85.4
# 2  1990-1994               63.8                81.8
# 3  1995-1999               41.0                71.4
# 4  2000-2004               27.6                65.0
# 5  2005-2009               43.4                70.4
# 6  2010-2014               28.4                63.8

# %% [markdown]
# ### Bar charts to compare tech & biotech vs. other in percentage of profitable IPOs from 1980-2014

# %%
data = pd.DataFrame({'Group' :['Tech & Biotech','Other','Tech & Biotech','Other','Tech & Biotech','Other','Tech & Biotech','Other','Tech & Biotech','Other','Tech & Biotech','Other','Tech & Biotech','Other'],
                     'Year Range'  :['1980-1984','1980-1984','1985-1989','1985-1989','1990-1994','1990-1994','1995-1999','1995-1999','2000-2004','2000-2004','2004-2009','2004-2009','2010-2014','2010-2014'],
                     'Percent Profitable IPOs':[80.0, 80.8, 72.2, 85.4, 63.8, 81.8, 41.00, 71.4, 27.6, 65.0, 43.4, 70.4, 28.4, 63.8]})
fig = Bar(data, label='Year Range', values='Percent Profitable IPOs', group='Group', legend='top_right')
show(fig)
# Out:
#     <div class="plotdiv" id="6033477a-dc0e-42be-82b2-90d1277941fa"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6033477a-dc0e-42be-82b2-90d1277941fa");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6033477a-dc0e-42be-82b2-90d1277941fa' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"dc9b47a4-1877-447f-8b57-d1ac19f8cafc":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"86bea4cb-a025-4efe-ad15-7183f21a4af3","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a2800b05-588a-49da-bf8b-c7869006952a","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x"],"data":{"chart_index":[{"year":1982}],"color":["#407ee7"],"fill_alpha":[0.8],"height":[82.0],"line_alpha":[1.0],"line_color":["white"],"width":[0.02002281575987929],"x":["1982:0.0833333333333"],"y":[41.0],"year":[1982]}},"id":"941e10e0-b482-45e9-b087-d7c815c0b89b","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"0765c671-e76d-4a4b-a68b-604abf13092a","type":"ColumnDataSource"},"glyph":{"id":"909315d8-502f-4c76-8bc7-23ee833154d0","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"ba613f3c-6d1d-4d9d-9f0f-d7cb6e5e94ff","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x"],"data":{"chart_index":[{"year":2003}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[27.0],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["2003"],"y":[13.5],"year":[2003]}},"id":"87348bae-ce75-4533-a5e0-f2fe7c183f0a","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e42cc0f4-0701-40f3-809e-a486bf070eca","type":"Rect"},{"attributes":{"data_source":{"id":"34bcda61-34cf-4157-8f6c-384a995f33f5","type":"ColumnDataSource"},"glyph":{"id":"94219828-899f-4a63-9e86-6527cf980eb5","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"516b372a-7fff-4816-8c7c-6be89aa032cf","type":"GlyphRenderer"},{"attributes":{},"id":"c8f101ef-9872-49b0-9738-2633d2832aa9","type":"CategoricalTicker"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"02940539-1d9a-4996-a5cf-47ff01923655","type":"Rect"},{"attributes":{"plot":{"id":"f35c2726-66aa-47ee-a759-1c3dcdf37821","subtype":"Chart","type":"Plot"}},"id":"bb1804d2-91df-403a-83ac-019e0bb3d797","type":"ResizeTool"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4a4fe9ad-08e3-40e7-876b-868eac0161b0","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x"],"data":{"chart_index":[{"year":2008}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[57.0],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["2008"],"y":[28.5],"year":[2008]}},"id":"50528217-54f8-45b5-8c92-323b3c15b406","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"92225665-ac32-4b3c-b680-3570e4aba8b5","type":"ColumnDataSource"},"glyph":{"id":"2bdec77b-97dc-45fa-a2cc-b0064b6ffaba","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"ca4a12b8-58a5-46e1-872a-32fba9ad86fc","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha", ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[26]</strong>&gt;</code></p>
