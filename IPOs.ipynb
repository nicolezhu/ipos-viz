# %% [markdown]
# ## Loading the original data file (saved as a csv from the original Excel file)
#
#
# Import `pandas` (imported as `pd` to save typing).
#
# ```python
# import pandas as pd
# ipos = pd.read_csv('data/ipos.csv')
# ipos.head()
# ```
#
# Press _shift-enter_ to execute the code.

# %%
import pandas as pd
ipos = pd.read_csv('data/ipos.csv')
ipos.head()
# Out:
#    Year  Number of IPOs % Profitable  Number of IPOs.1 % Profitable.1
# 0  1980              25          88%                46            70%
# 1  1981              82          81%               110            85%
# 2  1982              44          82%                33            79%
# 3  1983             194          68%               257            86%
# 4  1984              52          81%               121            84%

# %% [markdown]
# ### Rename columns
#
# Rename column names (Excel spreadsheet didn't note which columns were Tech & Biotech and which were Other IPOs.
#
# ```python
# ipos = ipos.rename(columns={
#         'Year': 'year',
#         'Number of IPOs': 'num_ipos_tech',
#         '% Profitable': 'percentprof_tech',
#         'Number of IPOs.1': 'num_ipos_other',
#         '% Profitable.1': 'percentprof_other',
#     })
# ipos.head()
# ```

# %%
ipos = ipos.rename(columns={
        'Year': 'year',
        'Number of IPOs': 'num_ipos_tech',
        '% Profitable': 'percentprof_tech', 
        'Number of IPOs.1': 'num_ipos_other', 
        '% Profitable.1': 'percentprof_other', 
    })
ipos.head()
# Out:
#    year  num_ipos_tech percentprof_tech  num_ipos_other percentprof_other
# 0  1980             25              88%              46               70%
# 1  1981             82              81%             110               85%
# 2  1982             44              82%              33               79%
# 3  1983            194              68%             257               86%
# 4  1984             52              81%             121               84%

# %% [markdown]
# ### Clean data
#
# Remove percentage signs in the % profitable columns and convert the strings to floats, so we just have numbers to work with (the column descriptions also already describe the format of the data).
#
# ```python
# ipos['percentprof_tech'] = ipos['percentprof_tech'].map(lambda x: str(x)[:-1]).astype(float)
# ipos['percentprof_other'] = ipos['percentprof_other'].map(lambda x: str(x)[:-1]).astype(float)
# ipos.head()
# ```

# %%
ipos['percentprof_tech'] = ipos['percentprof_tech'].map(lambda x: str(x)[:-1]).astype(float)
ipos['percentprof_other'] = ipos['percentprof_other'].map(lambda x: str(x)[:-1]).astype(float)
ipos.head()
# Out:
#    year  num_ipos_tech  percentprof_tech  num_ipos_other  percentprof_other
# 0  1980             25                88              46                 70
# 1  1981             82                81             110                 85
# 2  1982             44                82              33                 79
# 3  1983            194                68             257                 86
# 4  1984             52                81             121                 84

# %% [markdown]
# ### Summary statistics
# `describe` function shows basic summary stats for every numeric column in the `DataFrame`
#
# ```python
# ipos.describe()
# ```

# %%
ipos.describe()
# Out:
#               year  num_ipos_tech  percentprof_tech  num_ipos_other  \
# count    35.000000      35.000000         35.000000       35.000000
# mean   1997.000000     102.542857         50.914286      127.742857
# std      10.246951      92.089261         23.243432      100.413950
# min    1980.000000       7.000000         11.000000       14.000000
# 25%    1988.500000      40.500000         31.000000       48.500000
# 50%    1997.000000      72.000000         54.000000       82.000000
# 75%    2005.500000     132.000000         69.500000      199.500000
# max    2014.000000     382.000000         88.000000      355.000000
#
#        percentprof_other
# count          35.000000
# mean           74.085714
# std            10.293834
# min            50.000000
# 25%            69.500000
# 50%            75.000000
# 75%            84.000000
# max            88.000000

# %% [markdown]
# ### Computing number of profitable IPOs for each group
#
# Add a column reflecting the actual number of profitable IPOs for (1) Tech & Biotech and (2) Other.
#
# ```python
# ipos['num_prof_tech'] = ( (ipos['percentprof_tech'] / 100) * ipos['num_ipos_tech'] )
# ipos['num_prof_other'] = ( (ipos['percentprof_other'] / 100) * ipos['num_ipos_other'] )
# ipos.head()
# ```

# %%
ipos['num_prof_tech'] = ( (ipos['percentprof_tech'] / 100) * ipos['num_ipos_tech'] )
ipos['num_prof_other'] = ( (ipos['percentprof_other'] / 100) * ipos['num_ipos_other'] )
ipos['num_loss_tech'] = ( ((100 - ipos['percentprof_tech']) / 100) * ipos['num_ipos_tech'] )
ipos['num_loss_other'] = ( ((100 - ipos['percentprof_other']) / 100) * ipos['num_ipos_other'] )
ipos.head(10)
# Out:
#    year  num_ipos_tech  percentprof_tech  num_ipos_other  percentprof_other  \
# 0  1980             25                88              46                 70
# 1  1981             82                81             110                 85
# 2  1982             44                82              33                 79
# 3  1983            194                68             257                 86
# 4  1984             52                81             121                 84
# 5  1985             42                79             145                 87
# 6  1986            102                64             291                 84
# 7  1987             69                75             216                 85
# 8  1988             30                74              72                 87
# 9  1989             39                69              74                 84
#
#    num_prof_tech  num_prof_other  num_loss_tech  num_loss_other
# 0          22.00           32.20           3.00           13.80
# 1          66.42           93.50          15.58           16.50
# 2          36.08           26.07           7.92            6.93
# 3         131.92          221.02          62.08           35.98
# 4          42.12          101.64           9.88           19.36
# 5          33.18          126.15           8.82           18.85
# 6          65.28          244.44          36.72           46.56
# 7          51.75          183.60          17.25           32.40
# 8          22.20           62.64           7.80            9.36
# 9          26.91           62.16          12.09           11.84

# %% [markdown]
# ## Loading Bokeh for basic visualizations

# %%
from bokeh.charts import Bar, Scatter, output_file, show, output_notebook
from bokeh.sampledata.autompg import autompg as df
from bokeh.models import HoverTool
output_notebook()

scatterplot1 = Scatter(ipos, x='year', y='percentprof_other', title="Percent of profitable companies (other) 1980-2014",
            xlabel="Year")

# output_file("scatterplot.html")

show(scatterplot1)
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="59e5d6f5-6092-48ec-bbde-33c1ba603408">Loading BokehJS ...</span>
#     </div>
#     <div class="plotdiv" id="f019ef4c-6270-4c6f-9dc8-993e2615e3ab"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f019ef4c-6270-4c6f-9dc8-993e2615e3ab");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f019ef4c-6270-4c6f-9dc8-993e2615e3ab' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"bf35c92c-91df-470a-88dd-15d873add294":{"roots":{"references":[{"attributes":{"plot":{"id":"384e5955-4333-4128-8b7f-f55df1478195","subtype":"Chart","type":"Plot"}},"id":"e23c2081-1917-414a-9d7e-17bb6167b06b","type":"HelpTool"},{"attributes":{"plot":{"id":"384e5955-4333-4128-8b7f-f55df1478195","subtype":"Chart","type":"Plot"}},"id":"dbcf335e-a464-4763-b065-1227d5f65b48","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"15b7da7e-7071-4430-ae49-2f1d0ece9be8","type":"BoxAnnotation"},"plot":{"id":"384e5955-4333-4128-8b7f-f55df1478195","subtype":"Chart","type":"Plot"}},"id":"9ee39207-03d0-44d6-873c-c08deb5931ef","type":"BoxZoomTool"},{"attributes":{},"id":"2f53470f-1a23-4567-8ea5-608f96ec2b61","type":"BasicTickFormatter"},{"attributes":{},"id":"480bc1d7-62ea-402c-9fa6-b102a37de037","type":"BasicTicker"},{"attributes":{},"id":"b4d95c85-4ea3-432a-bb79-687a126213b9","type":"ToolEvents"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],"x_values":[1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014],"y_values":
type":"WheelZoomTool"},{"attributes":{"plot":{"id":"80b0d2d5-ccb4-4367-b4ba-3a45c3da9a0b","subtype":"Chart","type":"Plot"}},"id":"5abdee5d-f352-44df-855b-8ff8198bdff4","type":"HelpTool"},{"attributes":{"overlay":{"id":"28d79012-2596-4c24-9ecc-b42cf529102e","type":"BoxAnnotation"},"plot":{"id":"80b0d2d5-ccb4-4367-b4ba-3a45c3da9a0b","subtype":"Chart","type":"Plot"}},"id":"d670c64c-0150-4cc6-ba3b-e888be6a0bf9","type":"BoxZoomTool"},{"attributes":{},"id":"252b0856-b8dc-4db5-a3a9-ed322bb66e1d","type":"BasicTicker"},{"attributes":{"plot":{"id":"80b0d2d5-ccb4-4367-b4ba-3a45c3da9a0b","subtype":"Chart","type":"Plot"}},"id":"fb5b3825-a72e-4c1d-b640-b670f95343d8","type":"ResizeTool"},{"attributes":{},"id":"b4d95c85-4ea3-432a-bb79-687a126213b9","type":"ToolEvents"},{"attributes":{},"id":"480bc1d7-62ea-402c-9fa6-b102a37de037","type":"BasicTicker"},{"attributes":{"data_source":{"id":"6f3951a0-6b51-49c4-a0e2-991b24d792e6","type":"ColumnDataSource"},"glyph":{"id":"0e80ea17-2f6d-42cd-87c4-0af8a5acb126","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"5feeaabf-1e82-41ac-b823-80a3705a3995","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],"x_values":[1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014],"y_values":[70.0,85.0,79.0,86.0,84.0,87.0,84.0,85.0,87.0,84.0,87.0,88.0,80.0,74.0,80.0,75.0,74.0,76.0,69.0,63.0,50.0,66.0,63.0,76.0,70.0,70.0,80.0,74.0,57.0,71.0,71.0,60.0,75.0,56.0,57.0]}},"id":"c58a49d1-561e-4ab6-acd5-c69d9ccf94fa","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],"x_values":[1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014],"y_values":[88.0,81.0,82.0,68.0,81.0,79.0,64.0,75.0,74.0,69.0,83.0,55.0,54.0,64.0,63.0,65.0,43.0,46.0,37.0,14.0,13.0,24.0,42.0,27.0,32.0,30.0,36.0,24.0,57.0,70.0,48.0,29.0,35.0,19.0,11.0]}},"id":"6f3951a0-6b51-49c4-a0e2-991b24d792e6","type":"ColumnDataSource"},{"attributes":{"below":[{"id":"236ef886-883e-4857-ba81-de7250efc325","type":"LinearAxis"}],"left":[{"id":"0baed551-f5dc-4ad2-9c6 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[7]</strong>&gt;</code></p>

# %% [markdown]
# ### Tech & Biotech: comparing the number of IPOs to the number of profitable IPOs

# %%
from bokeh.plotting import figure
prof_tech = figure(plot_width=400, plot_height=400)
prof_tech.line(ipos["year"], ipos["num_ipos_tech"],
             color="firebrick", line_width=4, legend="number of tech & biotech IPOs")
prof_tech.line(ipos["year"], ipos["num_prof_tech"],
             color="navy", line_width=4, legend="number of profitable tech & biotech IPOs")
show(prof_tech)
# Out:
#     <div class="plotdiv" id="f0a4169c-68ff-4bea-8107-56aa0db4c353"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f0a4169c-68ff-4bea-8107-56aa0db4c353");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f0a4169c-68ff-4bea-8107-56aa0db4c353' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"1d7ce6ff-91c6-4b7c-97ae-aa942567293f":{"roots":{"references":[{"attributes":{"plot":{"id":"80b0d2d5-ccb4-4367-b4ba-3a45c3da9a0b","subtype":"Chart","type":"Plot"}},"id":"d3679414-37ae-4b67-ae4b-9f8ee13722ac","type":"PreviewSaveTool"},{"attributes":{"plot":{"id":"384e5955-4333-4128-8b7f-f55df1478195","subtype":"Chart","type":"Plot"}},"id":"e23c2081-1917-414a-9d7e-17bb6167b06b","type":"HelpTool"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014],"y":[25,82,44,194,52,42,102,69,30,39,35,103,146,154,137,226,321,194,125,382,317,29,25,26,91,61,72,94,7,17,44,44,49,84,127]}},"id":"5b4b60fb-b597-470d-8b77-503edebb5cde","type":"ColumnDataSource"},{"attributes":{"overlay":{"id":"6d051c3b-3d4e-4e73-8789-f12ae60002c4","type":"BoxAnnotation"},"plot":{"id":"683fa694-5195-4c0b-9ee5-ee99557ac8c2","subtype":"Figure","type":"Plot"}},"id":"67edf189-0f35-41cc-a910-7810ca90c33b","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"683fa694-5195-4c0b-9ee5-ee99557ac8c2","subtype":"Figure","type":"Plot"}},"id":"8ae8aa02-edcf-486e-9872-a43f7ee15ca8","type":"HelpTool"},{"attributes":{"plot":{"id":"683fa694-5195-4c0b-9ee5-ee99557ac8c2","subtype":"Figure","type":"Plot"}},"id":"972a2383-2e75-4d9d-9dce-8ae4577564d3","type":"WheelZoomTool"},{"attributes":{"data_source":{"id":
plot":{"id":"683fa694-5195-4c0b-9ee5-ee99557ac8c2","subtype":"Figure","type":"Plot"},"ticker":{"id":"2702e851-ebfa-4b1f-b2bc-61ff754821ff","type":"BasicTicker"}},"id":"41123d87-1fe7-482f-a816-86067bb7a180","type":"LinearAxis"},{"attributes":{"data_source":{"id":"6f3951a0-6b51-49c4-a0e2-991b24d792e6","type":"ColumnDataSource"},"glyph":{"id":"0e80ea17-2f6d-42cd-87c4-0af8a5acb126","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"5feeaabf-1e82-41ac-b823-80a3705a3995","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],"x_values":[1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014],"y_values":[70.0,85.0,79.0,86.0,84.0,87.0,84.0,85.0,87.0,84.0,87.0,88.0,80.0,74.0,80.0,75.0,74.0,76.0,69.0,63.0,50.0,66.0,63.0,76.0,70.0,70.0,80.0,74.0,57.0,71.0,71.0,60.0,75.0,56.0,57.0]}},"id":"c58a49d1-561e-4ab6-acd5-c69d9ccf94fa","type":"ColumnDataSource"},{"attributes":{"below":[{"id":"236ef886-883e-4857-ba81-de7250efc325","type":"LinearAxis"}],"left":[{"id":"0baed551-f5dc-4ad2-9c6a-9f6ced48d827","type":"LinearAxis"}],"legend":null,"renderers":[{"id":"15b7da7e-7071-4430-ae49-2f1d0ece9be8","type":"BoxAnnotation"},{"id":"c05ebfe9-d1fb-4e59-bcce-c9c105556ef5","type":"GlyphRenderer"},{"id":"236ef886-883e-4857-ba81-de7250efc325","type":"LinearAxis"},{"id":"0baed551-f5dc-4ad2-9c6a-9f6ced48d827","type":"LinearAxis"},{"id":"340c2cdd-105c-4ce0-a51c-eb28d1209c96","type":"Grid"},{"id":"a8403e93-02f6-4135-bd39-ca3d23eb8b76","type":"Grid"}],"title":"Percent of profitable companies (other) 1980-2014","title_text_font_size":{"value":"14pt"},"tool_events":{"id":"b4d95c85-4ea3-432a-bb79-687a126213b9","type":"ToolEvents"},"tools":[{"id":"89cebc81-554b-4556-84fc-78260cdcb40c","type":"PanTool"},{"id":"dbcf335e-a464-4763-b065-1227d5f65b48","type":"W ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[9]</strong>&gt;</code></p>

# %% [markdown]
# ### Comparing "tech & biotech" vs. "other" in terms of % profitable IPOs

# %%
x1 = ipos["year"]
y1 = ipos["percentprof_tech"]
x2 = ipos["year"]
y2 = ipos["percentprof_other"]

percentprof = figure(plot_width=400, plot_height=400)
percentprof.multi_line([x1, x2], [y1, y2],
             color=["firebrick", "navy"], alpha=[0.8, 0.3], line_width=4)

show(percentprof)
# Out:
#     <div class="plotdiv" id="15292c36-c628-413e-88ea-cb6f3f9c3e6f"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("15292c36-c628-413e-88ea-cb6f3f9c3e6f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '15292c36-c628-413e-88ea-cb6f3f9c3e6f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"1ee42ef4-e6e2-403f-84c5-7c03b63653cb":{"roots":{"references":[{"attributes":{"plot":{"id":"384e5955-4333-4128-8b7f-f55df1478195","subtype":"Chart","type":"Plot"}},"id":"e23c2081-1917-414a-9d7e-17bb6167b06b","type":"HelpTool"},{"attributes":{},"id":"1eddb2c8-81dd-42f7-ac44-57923c16604f","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"0d3ff5a6-c8af-4311-9bc2-08b84696dc48","type":"ColumnDataSource"},"glyph":{"id":"17b88138-12df-427a-931d-87afbc85aecc","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"7c49c3c6-9de3-4f2a-9d64-9a76ce38667d","type":"Line"},"selection_glyph":null},"id":"2eaef28e-386f-4378-a356-6333bea40717","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"0e80ea17-2f6d-42cd-87c4-0af8a5acb126","type":"Circle"},{"attributes":{"formatter":{"id":"0006e9b8-1b94-4bb7-956a-be7334a007ee","type":"BasicTickFormatter"},"plot":{"id":"498e8f32-0fb3-4e6b-81e9-a127e84d4dbf","subtype":"Figure","type":"Plot"},"ticker":{"id":"e90f28f7-84da-4319-bf09-fc742983f042","type":"BasicTicker"}},"id":"723aa0e3-c321-4732-a3af-437a3fb12a45","type":"LinearAxis"},{"attributes":{"plot":{"id":"80b0d2d5-ccb4-4367-b4ba-3a45c3da9a0b","subtype":"Chart","type":"Plot"}},"id":"fb5b3825-a72e-4c1d-b640-b670f95343d8","type":"ResizeTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"15b7da7e-7071-4430-ae49-2f1d0ece9be8","type":"BoxAnnotation"},{"attributes":{"formatter":{"id":"2eb5c3af-3b1a-4be5-ac36-cc586b417337","type":"BasicTickFormatter"},"plot":{"id":"683fa694-5195-4c0b-9ee5-ee99557ac8c2","subtype":"Figure","type":"Plot"},"ticker":{"id":"2702e851-ebfa-4b1f-b2bc-61ff754821ff","type":"BasicTicker"}},"id":"41123d87-1fe7-482f-a816-86067bb7a180","type":"LinearAxis"},{"attributes":{"data_source":{"id":"6f3951a0-6b51-49c4-a0e2-991b24d792e6","type":"ColumnDataSource"},"glyph":{"id":"0e80ea17-2f6d-42cd-87c4-0af8a5acb126","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"5feeaabf-1e82-41ac-b823-80a3705a3995","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],"x_values":[1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014],"y_values":[70.0,85.0,79.0,86.0,84.0,87.0,84.0,85.0,87.0,84.0,87.0,88.0,80.0,74.0,80.0,75.0,74.0,76.0,69.0,63.0,50.0,66.0,63.0,76.0,70.0,70.0,80.0,74.0,57.0,71.0,71.0,60.0,75.0,56.0,57.0]}},"id":"c58a49d1-561e-4ab6-acd5-c69d9ccf94fa","type":"ColumnDataSource"},{"attributes":{"line_alpha":{"field":"line_alpha"},"line_color":{"field":"line_color"},"line_width":{"value":4},"xs":{"field":"xs"},"ys":{"field":"ys"}},"id":"96f3804b-4651-4a29-8c4e-18c2ea4be8e9","type":"MultiLine"},{"attributes":{"below":[{"id":"236ef886-883e-4857-ba81-de7250efc325","type":"LinearAxis"}],"left":[{"id":"0baed551-f5dc-4ad2-9c6a-9f6ced48d827","type":"LinearAxis"}],"legend":null,"renderers":[{"id":"15b7da7e-7071-4430-ae49-2f1d0ece9be8","type":"BoxAnnotation"},{"id":"c05ebfe9-d1fb-4e59-bcce-c9c105556ef5","type":"GlyphRenderer"},{"id":"236ef886-883e-4857-ba81-de7250efc325","type":"LinearAxis"},{"id":"0baed551-f5dc-4ad2-9c6a-9f6ced48d827","type":"LinearAxis"},{"id":"340c2cdd-105c-4ce0-a51c-eb28d1209c96","type":"Grid"},{"id":"a8403e93-02f6-4135-bd39-ca3d23eb8b76","type":"Grid"}] ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[10]</strong>&gt;</code></p>

# %% [markdown]
# ### Create new table grouping percent profitability of IPOs in 5 year ranges

# %%
start = 1980
end = 1984
percent_prof_tech = 0
percent_prof_other = 0
year_range = []
tech_data = []
other_data = []

for pos, i in enumerate(ipos["year"].tolist(), 0):
    percent_prof_tech += ipos["percentprof_tech"][pos]
    percent_prof_other += ipos["percentprof_other"][pos]
    if (pos+1) % 5 == 0:
        year_range.append("%s-%s" % (start,end))
        start += 5
        end += 5
        tech_data.append((percent_prof_tech / 500) * 100)
        other_data.append((percent_prof_other / 500) * 100)
        percent_prof_tech = 0
        percent_prof_other = 0

d = {'year_range': pd.Series(year_range),
     'percent_prof_other': pd.Series(other_data),
     'percent_prof_tech': pd.Series(tech_data)
    }

grouped_years = pd.DataFrame(d)
grouped_years = grouped_years[grouped_years.columns[::-1]]
grouped_years
# Out:
#   year_range  percent_prof_tech  percent_prof_other
# 0  1980-1984               80.0                80.8
# 1  1985-1989               72.2                85.4
# 2  1990-1994               63.8                81.8
# 3  1995-1999               41.0                71.4
# 4  2000-2004               27.6                65.0
# 5  2005-2009               43.4                70.4
# 6  2010-2014               28.4                63.8

# %% [markdown]
# ### Save new CSV

# %%
grouped_years.to_csv('data/to_chart.csv', index=False, encoding='utf-8')

# %% [markdown]
# ### Bar charts to compare tech & biotech vs. other in percentage of profitable IPOs from 1980-2014

# %%
data = pd.DataFrame({'Group' :['Tech & Biotech','Other','Tech & Biotech','Other','Tech & Biotech','Other','Tech & Biotech','Other','Tech & Biotech','Other','Tech & Biotech','Other','Tech & Biotech','Other'],
                     'Year Range'  :['1980-1984','1980-1984','1985-1989','1985-1989','1990-1994','1990-1994','1995-1999','1995-1999','2000-2004','2000-2004','2004-2009','2004-2009','2010-2014','2010-2014'],
                     'Percent Profitable IPOs':[80.0, 80.8, 72.2, 85.4, 63.8, 81.8, 41.00, 71.4, 27.6, 65.0, 43.4, 70.4, 28.4, 63.8]})
fig = Bar(data, label='Year Range', values='Percent Profitable IPOs', group='Group', legend='top_right')
show(fig)
# Out:
#     <div class="plotdiv" id="5f198a25-9123-45f5-aa14-635e556a0e5b"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("