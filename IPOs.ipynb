# %% [markdown]
# ## Loading the original data file (saved as a csv from the original Excel file)
#
#
# Import `pandas` (imported as `pd` to save typing).
#
# ```python
# import pandas as pd
# ipos = pd.read_csv('ipos.csv')
# ipos.head()
# ```
#
# Press _shift-enter_ to execute the code.

# %%
import pandas as pd
ipos = pd.read_csv('ipos.csv')
ipos.head()
# Out:
#    Year  Number of IPOs % Profitable  Number of IPOs.1 % Profitable.1
# 0  1980              25          88%                46            70%
# 1  1981              82          81%               110            85%
# 2  1982              44          82%                33            79%
# 3  1983             194          68%               257            86%
# 4  1984              52          81%               121            84%

# %% [markdown]
# ### Rename columns
#
# Rename column names (Excel spreadsheet didn't note which columns were Tech & Biotech and which were Other IPOs.
#
# ```python
# ipos = ipos.rename(columns={
#         'Year': 'year',
#         'Number of IPOs': 'num_ipos_tech',
#         '% Profitable': 'percentprof_tech',
#         'Number of IPOs.1': 'num_ipos_other',
#         '% Profitable.1': 'percentprof_other',
#     })
# ipos.head()
# ```

# %%
ipos = ipos.rename(columns={
        'Year': 'year',
        'Number of IPOs': 'num_ipos_tech',
        '% Profitable': 'percentprof_tech', 
        'Number of IPOs.1': 'num_ipos_other', 
        '% Profitable.1': 'percentprof_other', 
    })
ipos.head()
# Out:
#    year  num_ipos_tech percentprof_tech  num_ipos_other percentprof_other
# 0  1980             25              88%              46               70%
# 1  1981             82              81%             110               85%
# 2  1982             44              82%              33               79%
# 3  1983            194              68%             257               86%
# 4  1984             52              81%             121               84%

# %% [markdown]
# ### Clean data
#
# Remove percentage signs in the % profitable columns and convert the strings to floats, so we just have numbers to work with (the column descriptions also already describe the format of the data).
#
# ```python
# ipos['percentprof_tech'] = ipos['percentprof_tech'].map(lambda x: str(x)[:-1]).astype(float)
# ipos['percentprof_other'] = ipos['percentprof_other'].map(lambda x: str(x)[:-1]).astype(float)
# ipos.head()
# ```

# %%
ipos['percentprof_tech'] = ipos['percentprof_tech'].map(lambda x: str(x)[:-1]).astype(float)
ipos['percentprof_other'] = ipos['percentprof_other'].map(lambda x: str(x)[:-1]).astype(float)
ipos.head()
# Out:
#    year  num_ipos_tech  percentprof_tech  num_ipos_other  percentprof_other
# 0  1980             25                88              46                 70
# 1  1981             82                81             110                 85
# 2  1982             44                82              33                 79
# 3  1983            194                68             257                 86
# 4  1984             52                81             121                 84

# %% [markdown]
# ### Summary statistics
# `describe` function shows basic summary stats for every numeric column in the `DataFrame`
#
# ```python
# ipos.describe()
# ```

# %%
ipos.describe()
# Out:
#               year  num_ipos_tech  percentprof_tech  num_ipos_other  \
# count    35.000000      35.000000         35.000000       35.000000
# mean   1997.000000     102.542857         50.914286      127.742857
# std      10.246951      92.089261         23.243432      100.413950
# min    1980.000000       7.000000         11.000000       14.000000
# 25%    1988.500000      40.500000         31.000000       48.500000
# 50%    1997.000000      72.000000         54.000000       82.000000
# 75%    2005.500000     132.000000         69.500000      199.500000
# max    2014.000000     382.000000         88.000000      355.000000
#
#        percentprof_other
# count          35.000000
# mean           74.085714
# std            10.293834
# min            50.000000
# 25%            69.500000
# 50%            75.000000
# 75%            84.000000
# max            88.000000

# %% [markdown]
# ### Computing number of profitable IPOs for each group
#
# Add a column reflecting the actual number of profitable IPOs for (1) Tech & Biotech and (2) Other.
#
# ```python
# ipos['num_prof_tech'] = ( (ipos['percentprof_tech'] / 100) * ipos['num_ipos_tech'] )
# ipos['num_prof_other'] = ( (ipos['percentprof_other'] / 100) * ipos['num_ipos_other'] )
# ipos.head()
# ```

# %%
ipos['num_prof_tech'] = ( (ipos['percentprof_tech'] / 100) * ipos['num_ipos_tech'] )
ipos['num_prof_other'] = ( (ipos['percentprof_other'] / 100) * ipos['num_ipos_other'] )
ipos['num_loss_tech'] = ( ((100 - ipos['percentprof_tech']) / 100) * ipos['num_ipos_tech'] )
ipos['num_loss_other'] = ( ((100 - ipos['percentprof_other']) / 100) * ipos['num_ipos_other'] )
ipos.head()
# Out:
#     year  num_ipos_tech  percentprof_tech  num_ipos_other  percentprof_other  \
# 0   1980             25                88              46                 70
# 1   1981             82                81             110                 85
# 2   1982             44                82              33                 79
# 3   1983            194                68             257                 86
# 4   1984             52                81             121                 84
# 5   1985             42                79             145                 87
# 6   1986            102                64             291                 84
# 7   1987             69                75             216                 85
# 8   1988             30                74              72                 87
# 9   1989             39                69              74                 84
# 10  1990             35                83              75                 87
# 11  1991            103                55             183                 88
# 12  1992            146                54             266                 80
# 13  1993            154                64             355                 74
# 14  1994            137                63             266                 80
# 15  1995            226                65             235                 75
# 16  1996            321                43             355                 74
# 17  1997            194                46             280                 76
# 18  1998            125                37             156                 69
# 19  1999            382                14              95                 63
# 20  2000            317                13              64                 50
# 21  2001             29                24              50                 66
# 22  2002             25                42              41                 63
# 23  2003             26                27              37                 76
# 24  2004             91                32              82                 70
# 25  2005             61                30              98                 70
# 26  2006             72                36              85                 80
# 27  2007             94                24              65                 74
# 28  2008              7                57              14                 57
# 29  2009             17                70              24                 71
# 30  2010             44                48              47                 71
# 31  2011             44                29              37                 60
# 32  2012             49                35              44                 75
# 33  2013             84                19              73                 56
# 34  2014            127                11              79                 57
#
#     num_prof_tech  num_prof_other  num_loss_tech  num_loss_other
# 0           22.00           32.20           3.00           13.80
# 1           66.42           93.50          15.58           16.50
# 2           36.08           26.07           7.92            6.93
# 3          131.92          221.02          62.08           35.98
# 4           42.12          101.64           9.88           19.36
# 5           33.18          126.15           8.82           18.85
# 6           65.28          244.44          36.72           46.56
# 7           51.75          183.60          17.25           32.40
# 8           22.20           62.64           7.80            9.36
# 9           26.91           62.16          12.09           11.84
# 10          29.05           65.25           5.95            9.75
# 11          56.65          161.04          46.35           21.96
# 12          78.84          212.80          67.16           53.20
# 13          98.56          262.70          55.44           92.30
# 14          86.31          212.80          50.69           53.20
# 15         146.90          176.25          79.10           58.75
# 16         138.03          262.70         182.97           92.30
# 17          89.24          212.80         104.76           67.20
# 18          46.25          107.64          78.75           48.36
# 19          53.48           59.85         328.52           35.15
# 20          41.21           32.00         275.79           32.00
# 21           6.96           33.00          22.04           17.00
# 22          10.50           25.83          14.50           15.17
# 23           7.02           28.12          18.98            8.88
# 24          29.12           57.40          61.88           24.60
# 25          18.30           68.60          42.70           29.40
# 26          25.92           68.00          46.08           17.00
# 27          22.56           48.10          71.44           16.90
# 28           3.99            7.98           3.01            6.02
# 29          11.90           17.04           5.10            6.96
# 30          21.12           33.37          22.88           13.63
# 31          12.76           22.20          31.24           14.80
# 32          17.15           33.00          31.85           11.00
# 33          15.96           40.88          68.04           32.12
# 34          13.97           45.03         113.03           33.97

# %% [markdown]
# ## Loading Bokeh for basic visualizations

# %%
from bokeh.charts import Bar, Scatter, output_file, show, output_notebook
from bokeh.sampledata.autompg import autompg as df
from bokeh.models import HoverTool
output_notebook()

scatterplot = Scatter(ipos, x='year', y='num_prof_tech', title="Number of profitable tech & biotech companies",
            xlabel="Year")

# output_file("scatterplot.html")

# show(scatterplot)
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="36277d63-8989-4413-b9c8-97494f3af0fc">Loading BokehJS ...</span>
#     </div>

# %%
# from bokeh.charts import Bar
# p = Bar(
#     ipos, label='year', values='num_ipos_tech', title="Profitable IPOs", tools='crosshair'
# )

p = Scatter(ipos, x='year', y='num_prof_tech', title="Number of profitable tech & biotech companies",
            xlabel="Year")

show(p)
# Out:
#     <div class="plotdiv" id="25c64890-c7a6-4adb-b65a-3ebc9f36336d"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("25c64890-c7a6-4adb-b65a-3ebc9f36336d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '25c64890-c7a6-4adb-b65a-3ebc9f36336d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"5b0b6077-6aaf-4af1-845c-541f73bf0837":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x"],"data":{"chart_index":[{"year":1980}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[25.0],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["1980"],"y":[12.5],"year":[1980]}},"id":"51b1a463-fab0-455d-9018-d35f5d9eb31b","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"eb43aef9-ef4b-4584-bd0f-be9ee0c9754c","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"7dd0cc42-5d78-4466-b3ad-cfafac3df596","type":"Rect"},{"attributes":{"callback":null},"id":"46c70bc3-c433-4d05-8827-012390c05bdf","type":"DataRange1d"},{"attributes":{"plot":{"id":"b7704cee-bef3-4900-8513-ac70e9086ed6","subtype":"Figure","type":"Plot"}},"id":"ae8e4ef5-24bc-449d-8050-928edebad01b","type":"ResetTool"},{"attributes":{"formatter":{"id":"1317c9e2-10b1-4ee8-ad16-799b1c8c6852","type":"BasicTickFormatter"},"plot":{"id":"e0da2782-75cf-4b74-a73c-8639723b074f","subtype":"Figure","type":"Plot"},"ticker":{"id":"a18cb795-ab72-45ab-940e-5c99f4782725","type":"BasicTicker"}},"id":"f158e6d5-c107-4902-9bab-c639a63bc2ea","type":"LinearAxis"},{"attributes":{"callback":null},"id":"2fb8beca-59a3-4d41-a90a-b479d2379a8d","type":"DataRange1d"},{"attributes":{"plot":{"id":"a1b724af-a7d1-4600-85dd-e3ae1c8978d3","subtype":"Figure","type":"Plot"},"ticker":{"id":"5e1fa4f1-4dc3-4623-a7cb-8e8b9bfbfd06","type":"BasicTicker"}},"id":"a4def27d-9018-431d-b456-1a52bd92d6bd","type":"Grid"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x"],"data":{"chart_index":[{"year":1996}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[321.0],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["1996"],"y":[160.5],"year":[1996]}},"id":"091e5cc0-b502-4279-8971-ee8fda330273","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"5149c6c2-9132-44bf-be31-9912ab339a90","type":"ColumnDataSource"},"glyph":{"id":"e14f5fc6-659d-4c4b-ad3b-4e28f275f942","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"07f6e0b3-4b98-4a99-ad1d-1ab48f91b324","type":"GlyphRenderer"},{"attributes":{"legends":[["1980",[{"id":"84bc1b65-1200-4c79-9583-04797e6891d2","type":"GlyphRenderer"}]],["1981",[{"id":"a5f3a10e-732d-40e7-bce6-f5ec9d192d9e","type":"GlyphRenderer"}]],["1982",[{"id":"0fa0a5d8-6ec0-4af6-8d88-5d05f42c2896","type":"GlyphRenderer"}]],["1983",[{"id":"59c53b7e-ae9d-4398-a061-3c6af589a028","type":"GlyphRenderer"}]],["1984",[{"id":"a89047a8-0c07-4fce-ba72-5b810ae75941","type":"GlyphRenderer"}]],["1985",[{"id":"5cde357d-2d10-4451-b042-9468b6a67520","type":"GlyphRenderer"}]],["1986",[{"id":"5f150e6b-c00c-4f5e-b2d3-a31648b87d0d","type":"GlyphRenderer"}]],["1987",[{"id":"394cefc9-a93b-4d7d-8335-61165544cdc0","type":"GlyphRenderer"}]],["1988",[{"id":"dabbad38-09fc-4cd0-9346-e76240451a3e","type":"GlyphRenderer"}]],["1989",[{"id":"eeb258bc-3482-4b96-bcce-f954d161180c","type":"GlyphRenderer"}]],["1990",[{"id":"1d9139df-f3f3-4a15-ae67-2293585291e5","type":"GlyphRenderer"}]],["1991",[{"id":"41892626-585b-4a3f-b602-90cd11d5dfca","type":"GlyphRenderer"}]],["1992",[{"id":"bffa4854-3696-45ba-ace3-782cb9079fe7","type":"GlyphRenderer"}]],["1993",[{"id":"345c4d51-d9ce-419d-bb91-64fcf4ddcbe0","type":"GlyphRenderer"}]],["1994",[{"id":"37ab34b7-5f9a-4e5e-ae51-944a67f92d40","type":"GlyphRenderer"}]],["1995",[{"id":"25c53de6-bc1d-4da4-b0fa-894cffe01d92","type":"GlyphRenderer"}]],["1996",[{ ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[45]</strong>&gt;</code></p>

# %% [markdown]
# ### Tech & Biotech: comparing the number of IPOs to the number of profitable IPOs

# %%
prof_tech = figure(plot_width=400, plot_height=400)
prof_tech.line(ipos["year"], ipos["num_ipos_tech"],
             color="firebrick", line_width=4, legend="number of tech & biotech IPOs")
prof_tech.line(ipos["year"], ipos["num_prof_tech"],
             color="navy", line_width=4, legend="number of profitable tech & biotech IPOs")
# prof_tech.multi_line([ipos["year"], ipos["year"]], [ipos["num_ipos_tech"], ipos["num_prof_tech"]],
#              color=["firebrick", "navy"], alpha=[0.8, 0.3], line_width=4)
# add optional circles
# test2.circle(ipos["year"], ipos["num_ipos_tech"],
#              fill_color="white", size=6)
# test2.circle(ipos["year"], ipos["num_prof_tech"],
#              fill_color="black", size=6)
show(prof_tech)
# Out:
#     <div class="plotdiv" id="4256b10a-7695-42dd-a816-891ec70b59c6"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4256b10a-7695-42dd-a816-891ec70b59c6");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4256b10a-7695-42dd-a816-891ec70b59c6' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"bc3cd85c-b60a-4be1-8fab-71521b981b0f":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x"],"data":{"chart_index":[{"year":1980}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[25.0],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["1980"],"y":[12.5],"year":[1980]}},"id":"51b1a463-fab0-455d-9018-d35f5d9eb31b","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"eb43aef9-ef4b-4584-bd0f-be9ee0c9754c","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"7dd0cc42-5d78-4466-b3ad-cfafac3df596","type":"Rect"},{"attributes":{"callback":null},"id":"46c70bc3-c433-4d05-8827-012390c05bdf","type":"DataRange1d"},{"attributes":{"plot":{"id":"b7704cee-bef3-4900-8513-ac70e9086ed6","subtype":"Figure","type":"Plot"}},"id":"ae8e4ef5-24bc-449d-8050-928edebad01b","type":"ResetTool"},{"attributes":{"formatter":{"id":"1317c9e2-10b1-4ee8-ad16-799b1c8c6852","type":"BasicTickFormatter"},"plot":{"id":"e0da2782-75cf-4b74-a73c-8639723b074f","subtype":"Figure","type":"Plot"},"ticker":{"id":"